# %% [markdown]
# # Mapping evidence of Change - single- site

# %% [markdown]
# This notebook provides information on areas of annual habitat change.
#
# List of Subheadings for navigation:
# - 1. Area Selection
# - 2.
# - 3.
# - 4.
# - 5.
# - 6.
# - 7.

# %% [markdown]
# ## 1. Area Selection

# %% [markdown]
# ## 2. Change
#
# Here we visualise the areas of annual change within the Level 3 and Habitat map clasifications
#
# - Change should be identified in RED
# - There should be a selection tool for which years to visualise between
# - 3 date options should be avaviable

# %% [markdown]
# ### 2.1 Level 3 classification

# %% [markdown]
# #### 2.1.1 PLot Map
#
# - map should show oldest map, map highlighting change areas and newest map in a triple map series

# %% [markdown]
# #### 2.1.2 Table of outputs

# %% [markdown]
# #### 2.1.3 Graph of outputs

# %% [markdown]
# ### 2.2 Habitat map

# %% [markdown]
# #### 2.2.1 PLot Map
#
# - map should show oldest map, map highlighting change areas and newest map in a triple map series

# %% [markdown]
# #### 2.2.2 Table of outputs

# %% [markdown]
# #### 2.2.3 Graph of outputs

# %% [markdown]
# ### 2.2 Hydroperiod
#
# - This map is a cumulative heatmap which should show the two years overlaid and cumulatively added together

# %% [markdown]
# #### 2.2.1 PLot Map

# %% [markdown]
# #### 2.2.2 Table of outputs

# %% [markdown]
# #### 2.2.3 Graph of outputs

# %% [markdown]
# # 3. Export to PDF
#
# Select options to export
