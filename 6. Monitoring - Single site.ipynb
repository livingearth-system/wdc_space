# %% [markdown]
# # Monitoring - single- site

# %% [markdown]
# This notebook uses a pre prepared plan for a site as the end goal and monitors progress annually towards that goal.
#
# NB up to
#
# List of Subheadings for navigation:
# - 1.
# - 2.
# - 3.
# - 4.
# - 5.
# - 6.
# - 7.

# %% [markdown]
# ## 1. Area Selection

# %% [markdown]
# ## 2. Heading
#
# description

# %% [markdown]
# ### 2.1 Subheading PLOT

# %% [markdown]
# ### 2.2 Subheading TABLE

# %% [markdown]
# ### 2.3 Subheading GRAPH

# %% [markdown]
# ### 2.4 Subheading STATISTICS

# %% [markdown]
# ## 3. Heading
#
# description

# %% [markdown]
# ### 3.1 Subheading PLOT

# %% [markdown]
# ### 3.2 Subheading TABLE

# %% [markdown]
# ### 3.3 Subheading GRAPH

# %% [markdown]
# ### 3.4 Subheading STATISTICS

# %% [markdown]
# ## 4. Heading
#
# description

# %% [markdown]
# ### 4.1 Subheading PLOT

# %% [markdown]
# ### 4.2 Subheading TABLE

# %% [markdown]
# ### 4.3 Subheading GRAPH

# %% [markdown]
# ### 4.4 Subheading STATISTICS

# %% [markdown]
# ## 5. Heading
#
# description

# %% [markdown]
# ### 5.1 Subheading PLOT

# %% [markdown]
# ### 5.2 Subheading TABLE

# %% [markdown]
# ### 5.3 Subheading GRAPH

# %% [markdown]
# ### 5.4 Subheading STATISTICS
