# %% [markdown]
# # Standardised basic elements for Living Wales

# %% [markdown]
# # 0. Definitions and Terms

# %% [markdown]
# - ALL notebooks must have the same formatting - aka numbered and ### in the correct format
# - All outputs of the Area selections must have the same name/term - e.eg Site so that any area chosen can be used in the following notebook
# - Multi area selection must have defined the number of areas selected and the nomenclature must reflect this.
# - There needs to be an option for selection of very large datasets (aka SSSI dataset) to output big data
# - A way to associate other data to the habitat types

# %% [markdown]
# # 0. Single and Multi site Notebook template

# %% [markdown]
# # 1. Single Area Selection (including point, line and polygon selection)

# %% [markdown]
# # 2. Multi Area Selection (and Big data outputs)

# %% [markdown]
# NB adding abuffer

# %% [markdown]
# # 3. Standardised map selection for map output

# %% [markdown]
# # 4. Standardised Overlay options

# %% [markdown]
# # 5. Standardised Map output

# %% [markdown]
# # 6. Standardised table format

# %% [markdown]
# # 7. Standardised Pie chart format

# %% [markdown]
# # 8. Standardised Bar Chart format

# %% [markdown]
# # 9. Standardised Scatter Chart format

# %% [markdown]
# # 10. Hydroperiod heatmap (including lidar overlay)

# %% [markdown]
# # 11. Export to PDF, CSV or other format

# %% [markdown]
# # 12. Overlaying other datasets (e.g. hedgerow and runoff maps)

# %% [markdown]
# # 13 Map controls

# %% [markdown]
# from ipyleaflet import (
#     Map, basemaps, LayersControl, FullScreenControl, ZoomControl, ScaleControl, AttributionControl,
#     MeasureControl, DrawControl, SearchControl, TileLayer, WMSLayer, VideoOverlay, ImageOverlay
# )
# from ipywidgets import Layout
#
# Add controls to the map
# m.add_control(LayersControl(position='topright'))
# m.add_control(FullScreenControl())
# m.add_control(ZoomControl(position='topright'))
# m.add_control(ScaleControl(position='bottomleft'))
# m.add_control(AttributionControl(position='bottomright'))
# m.add_control(MeasureControl(position='topleft'))
# draw_control = DrawControl()
# m.add_control(draw_control)
# search_control = SearchControl(position='topleft', url='https://nominatim.openstreetmap.org/search?format=json&q={s}')
# m.add_control(search_control)
#
#
#
# OR DISPLAY MAP WHICH ALLOWS FOR selection
# # Loading shapefile plots from shapefile
# shapefile_plots = gpd_df
#
# # Transform shapefile boundaries into geographic data (and affect a style)
# geo_data = GeoData(
#     geo_dataframe=shapefile_plots.to_crs(epsg=4326),
#     style={
#         "color": "black",
#         "fillColor": "#3366cc",
#         "opacity": 0.05,
#         "weight": 1.9,
#         "dashArray": "2",
#         "fillOpacity": 0.6,
#     },
#     hover_style={"fillColor": "red", "fillOpacity": 0.2},
#     name="Shapefile",
# )
#
# # map the geographic data
# m = map_geom(geo_data)
#
# # Run display tool
# m, option_widget = draw_select(geo_data)
# m.add_layer(geo_data)
# m
